# %%
import argparse
import torch
import torch.distributed as dist
import torch.multiprocessing as mp
from torch.nn.parallel import DistributedDataParallel as DDP
import numpy as np
import models.ULIP_models as models
from utils.tokenizer import SimpleTokenizer
from utils.utils import get_model, get_dataset
from data.shapenet_3d import *
import torch.multiprocessing as mp
import gc
mp.set_start_method('spawn', force=True)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
class Args:
    def __init__(self):
        self.ckpt_path = "ckpt/ULIP-2-PointBERT-10k-colored-pc-pretrained.pt"  # Path to the pretrained checkpoint
        self.model = "ULIP2_PointBERT_Colored"  # Model architecture to use
        self.batch_size = 1  # Batch size for inference

args = Args()

# %%
def load_model(args):
    """Load the ULIP-2 model from a checkpoint"""
    print(f"Loading model {args.model} from {args.ckpt_path}...")
    ckpt = torch.load(args.ckpt_path, map_location='cpu')
    state_dict = {k.replace('module.', ''): v for k, v in ckpt['state_dict'].items()}

    model = getattr(models, args.model)(args=args)
    model.load_state_dict(state_dict, strict=False)
    model.cuda().eval()
    return model

# Load the model
model = load_model(args)
# Out:
# Loading model ULIP2_PointBERT_Colored from ckpt/ULIP-2-PointBERT-10k-colored-pc-pretrained.pt...
# Get openclip model:
# Finished loading the openclip model.
# training from scratch for pointbert.
# model size:
# 32.50M

# %%
def load_point(ply_file, device='cuda'):
    """Load point cloud from a .ply file."""
    verts, _ = pytorch3d.io.load_ply(ply_file)
    assert isinstance(verts, torch.Tensor) and verts.shape[1] == 3, "The point cloud should be 3D"
    
    # Add default RGB values (zeros)
    rgb = torch.zeros_like(verts)
    point_cloud = torch.cat([verts, rgb], dim=1)
    
    # Verify final dimensions and move to device
    assert point_cloud.shape[1] == 6, f"Expected 6 channels (XYZ+RGB), got {point_cloud.shape[1]}"
    
    return point_cloud.to(device)

# %%
def extract_features_from_ply(model, ply_file, device='cuda'):
    """Extract features from a single point cloud using the ULIP-2 model."""
    # Load the point cloud
    point_cloud = load_point(ply_file, device=device)
    
    # Reshape the point cloud to have batch dimension
    point_cloud = point_cloud.unsqueeze(0)  # Shape: (1, N, 6)
    
    # Extract features using the model
    with torch.no_grad():
        features = get_model(model).encode_pc(point_cloud)
        features = features / features.norm(dim=-1, keepdim=True)
        
    return features.cpu().numpy()

def extract_features_from_text(model, text, device='cuda'):
    """Extract features from a single text input using the ULIP-2 model."""
    # Tokenize the text
    tokenizer = SimpleTokenizer()
    tokens = tokenizer(text)
    
    # Convert tokens to tensor and move to device
    tokens_tensor = torch.tensor(tokens).unsqueeze(0).to(device)  # Shape: (1, L)
    
    # Extract features using the model
    with torch.no_grad():
        features = get_model(model).encode_text(tokens_tensor)
        features = features / features.norm(dim=-1, keepdim=True)
        
    return features.cpu().numpy()

# %%
text = "A red car"
text_feature = extract_features_from_text(model, text)
print("Text feature shape:", text_feature.shape)
# Out:
# /tmp/ipykernel_203592/3820353278.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tokens_tensor = torch.tensor(tokens).unsqueeze(0).to(device)  # Shape: (1, L)
# Text feature shape: (1, 1280)

# %%
def load_npy(npy_file):
    """Load a .npy file containing point cloud data."""
    data = np.load(npy_file)
    assert data.ndim == 2 and data.shape[1] == 6, "The .npy file should contain 6D point cloud data"
    return torch.tensor(data, dtype=torch.float32)

def calculate_similarity(features1, features2):
    """Calculate cosine similarity between two feature sets."""
    assert features1.shape == features2.shape, "Feature sets must have the same shape"
    similarity = np.dot(features1, features2.T)
    return similarity

# %%
ROOT_DIR = "/home/davidyyd/3dm/Shapenet/vis_results/SDFusion"
MODEL_DIR = [os.path.join(ROOT_DIR, d) for d in os.listdir(ROOT_DIR) if os.path.isdir(os.path.join(ROOT_DIR, d))]
PC_FILES = [os.path.join(d, "generated", "points_normalize.ply") for d in MODEL_DIR]

# %%
for ply_file in PC_FILES:
    print(f"Processing {ply_file}...")
    point_feature = extract_features_from_ply(model, ply_file)
    
    # save the features as ulip_feature.npy
    np.save(os.path.join(os.path.dirname(ply_file),"ulip_feature.ply"), point_feature)
    # print(f"Saved features to {ply_file.replace('.ply', '_ulip_feature.npy')}")
# Out:
# Processing /home/davidyyd/3dm/Shapenet/vis_results/SDFusion/f497cbcc4895d5386b684500e5db87c2/generated/points_normalize.ply...
# Processing /home/davidyyd/3dm/Shapenet/vis_results/SDFusion/395868f297f01d2d492d9da2668ec34c/generated/points_normalize.ply...
# Processing /home/davidyyd/3dm/Shapenet/vis_results/SDFusion/e9df7789d02eb998c8687ff9b0b4e4ac/generated/points_normalize.ply...
# Processing /home/davidyyd/3dm/Shapenet/vis_results/SDFusion/b6758a9b899d540919fb4103277a6b93/generated/points_normalize.ply...
# Processing /home/davidyyd/3dm/Shapenet/vis_results/SDFusion/186f6c911a4255bc1b17743c18fb63dc/generated/points_normalize.ply...
# Processing /home/davidyyd/3dm/Shapenet/vis_results/SDFusion/86b6e539e72be6d46fa0ab61d9f9d96d/generated/points_normalize.ply...
# Processing /home/davidyyd/3dm/Shapenet/vis_results/SDFusion/ffdc46ab1cfe759ce6fe3612af521500/generated/points_normalize.ply...
# ...

# %%
# calculate similarity
features_list = []
for ply_file in ply_files:
    features = np.load(ply_file.replace('.ply', '_features.npy'))
    features_list.append(features)
similarity_matrix = np.zeros((len(features_list), len(features_list)))
for i in range(len(features_list)):
    for j in range(len(features_list)):
        similarity_matrix[i][j] = calculate_similarity(features_list[i], features_list[j])
print("Similarity matrix:")
print(similarity_matrix)
# Out:
# Similarity matrix:
# [[0.99999988 0.99390501 0.99378866 0.99406528]
#  [0.99390501 1.         0.99393326 0.99459052]
#  [0.99378866 0.99393326 1.         0.99542034]
#  [0.99406528 0.99459052 0.99542034 0.99999994]]

# %%
# Now load all the results files
SDFusion_Results_plys = []
ROOT_DIR = "/workspace/vis_results/SDFusion/results/"
for category in os.listdir(ROOT_DIR):
    category_dir = os.path.join(ROOT_DIR, category)
    if os.path.isdir(category_dir):
        for subdir in os.listdir(category_dir):
            subdir_path = os.path.join(category_dir, subdir, "normalize")
            if os.path.isdir(subdir_path):
                for file in os.listdir(subdir_path):
                    if file.endswith('_normalize.ply'):
                        SDFusion_Results_plys.append(os.path.join(subdir_path, file))
# Save to the npy to same dir of the file

for ply_file in SDFusion_Results_plys:
    features = extract_features_from_ply(model, ply_file)
    print(f"Extracted features for {ply_file}: {features.shape}")
    # Save the features to a file
    np.save(os.path.join(os.path.dirname(ply_file),"ulip_feature.npy"), features)
    print(f"Features saved to {os.path.join(os.path.dirname(ply_file),'ulip_feature.npy')}")
# Out:
# Extracted features for /workspace/vis_results/SDFusion/results/chair/1055f78d441d170c4f3443b22038d340/normalize/points_normalize.ply: (1, 1280)
# Features saved to /workspace/vis_results/SDFusion/results/chair/1055f78d441d170c4f3443b22038d340/normalize/ulip_feature.npy
# Extracted features for /workspace/vis_results/SDFusion/results/chair/10dc303144fe5d668d1b9a1d97e2846/normalize/points_normalize.ply: (1, 1280)
# Features saved to /workspace/vis_results/SDFusion/results/chair/10dc303144fe5d668d1b9a1d97e2846/normalize/ulip_feature.npy
# Extracted features for /workspace/vis_results/SDFusion/results/chair/11525a18678f7ce6ae1e1181f20bb9c8/normalize/points_normalize.ply: (1, 1280)
# Features saved to /workspace/vis_results/SDFusion/results/chair/11525a18678f7ce6ae1e1181f20bb9c8/normalize/ulip_feature.npy
# Extracted features for /workspace/vis_results/SDFusion/results/chair/13076ebf8b5cc457b8d6f69a14683de3/normalize/points_normalize.ply: (1, 1280)
# ...

# %%
# remove all the .npy files under ROOT_DIR

import shutil
# os.walk(ROOT_DIR)

for root, dirs, files in os.walk(ROOT_DIR):
    for file in files:
        if file.endswith('.npy'):
            os.remove(os.path.join(root, file))
            print(f"Removed {os.path.join(root, file)}")
# Out:
# Removed /workspace/vis_results/SDFusion/results/chair/1055f78d441d170c4f3443b22038d340/points_normalize_features.npy
# Removed /workspace/vis_results/SDFusion/results/chair/1055f78d441d170c4f3443b22038d340/normalize/points_normalize_features.npy
# Removed /workspace/vis_results/SDFusion/results/chair/10dc303144fe5d668d1b9a1d97e2846/points_normalize_features.npy
# Removed /workspace/vis_results/SDFusion/results/chair/10dc303144fe5d668d1b9a1d97e2846/normalize/points_normalize_features.npy
# Removed /workspace/vis_results/SDFusion/results/chair/11525a18678f7ce6ae1e1181f20bb9c8/points_normalize_features.npy
# Removed /workspace/vis_results/SDFusion/results/chair/11525a18678f7ce6ae1e1181f20bb9c8/normalize/points_normalize_features.npy
# Removed /workspace/vis_results/SDFusion/results/chair/13076ebf8b5cc457b8d6f69a14683de3/points_normalize_features.npy
# Removed /workspace/vis_results/SDFusion/results/chair/13076ebf8b5cc457b8d6f69a14683de3/normalize/points_normalize_features.npy
# ...

# %%
# Now load all the results files
Michelangelo_Results_plys = []
ROOT_DIR = "/workspace/vis_results/Michelangelo/results"
for modeldir in os.listdir(ROOT_DIR):
    model_dir = os.path.join(ROOT_DIR, modeldir)
    if os.path.isdir(model_dir):
        normalize_dir = os.path.join(model_dir, "normalize")
        if os.path.isdir(normalize_dir):
            for file in os.listdir(normalize_dir):
                if file.endswith('_normalize.ply'):
                    Michelangelo_Results_plys.append(os.path.join(normalize_dir, file))
# Save to the npy to same dir of the file

for ply_file in Michelangelo_Results_plys:
    features = extract_features_from_ply(model, ply_file)
    print(f"Extracted features for {ply_file}: {features.shape}")
    # Save the features to a file
    np.save(os.path.join(os.path.dirname(ply_file),"ulip_feature.npy"), features)
    print(f"Features saved to {os.path.join(os.path.dirname(ply_file),'ulip_feature.npy')}")
# Out:
# Extracted features for /workspace/vis_results/Michelangelo/results/10f7179292b04787cf335697521a6511/normalize/points_normalize.ply: (1, 1280)
# Features saved to /workspace/vis_results/Michelangelo/results/10f7179292b04787cf335697521a6511/normalize/ulip_feature.npy
# Extracted features for /workspace/vis_results/Michelangelo/results/1399af537cd5f80723a295070ca176a0/normalize/points_normalize.ply: (1, 1280)
# Features saved to /workspace/vis_results/Michelangelo/results/1399af537cd5f80723a295070ca176a0/normalize/ulip_feature.npy
# Extracted features for /workspace/vis_results/Michelangelo/results/18943947ce3b8cae8a94168388287ad5/normalize/points_normalize.ply: (1, 1280)
# Features saved to /workspace/vis_results/Michelangelo/results/18943947ce3b8cae8a94168388287ad5/normalize/ulip_feature.npy
# Extracted features for /workspace/vis_results/Michelangelo/results/1a1a0794670a2114d6bef0ac9b3a5962/normalize/points_normalize.ply: (1, 1280)
# ...

# %%
import pandas as pd
from tqdm import tqdm
# Retrieve from "/home/davidyyd/3dm/Shapenet/dataset/ShapeNetCore.v1"
SHAPENET_DIR = "/home/davidyyd/3dm/Shapenet/dataset/ShapeNetCore.v1"
metadata_df = pd.read_csv("/home/davidyyd/3dm/Shapenet/Michelangelo/shapenet_metadata_sampled_rnd2.csv")

# %%
# For every model in ROOT_DIR, use its modelId and ulip_feature.npy to retrieve top 5 similar models from SHAPENET_DIR (use modelId to get synsetId from metadata_df, Then, traverse os.path.join(SHAPENET_DIR, synsetId) to get all the ref models dir, each dir has a ulip_feature.npy file, then calculate the similarity with the ulip_feature.npy of the model in ROOT_DIR, and get the top 5 similar models from the SHAPENET_DIR)
results = []
for modeldir in tqdm(os.listdir(ROOT_DIR)):
    model_dir = os.path.join(ROOT_DIR, modeldir)
    if os.path.isdir(model_dir):
        new_entry = {}
        modelId = modeldir
        # Get the synsetId from metadata_df
        synsetId = metadata_df[metadata_df['modelId'] == modelId]['synsetId'].values[0]
        category = metadata_df[metadata_df['modelId'] == modelId]['category'].values[0]
        # Get the ulip_feature.npy of the model in ROOT_DIR
        ulip_feature_path = os.path.join(model_dir, "points_normalize_ulip_feature.npy")
        ulip_feature = np.load(ulip_feature_path)
        # Get the ulip_feature.npy of the ref models in SHAPENET_DIR
        ref_model_dir = os.path.join(SHAPENET_DIR, f"0{synsetId}")
        ref_model_dirs = [os.path.join(ref_model_dir, d) for d in os.listdir(ref_model_dir) if os.path.isdir(os.path.join(ref_model_dir, d))]
        # Get the ulip_feature.npy of the ref models
        new_entry["query_model_id"] = modelId
        new_entry["query_feature_path"] = ulip_feature_path
        new_entry["category"] = category
        new_entry["retrieved_list"] = []
        ref_model_features = []
        for ref_model_dir in ref_model_dirs:
            ref_modelId = os.path.basename(ref_model_dir)
            ref_ulip_feature_path = os.path.join(ref_model_dir, "ulip_feature.npy")
            if os.path.exists(ref_ulip_feature_path):
                ref_ulip_feature = np.load(ref_ulip_feature_path)
                ref_model_features.append((ref_modelId, ref_ulip_feature))
        # Calculate the similarity with the ulip_feature.npy of the model in ROOT_DIR
        similarity_scores = []
        for ref_modelId, ref_ulip_feature in ref_model_features:
            # query: (1,1280), ref: (1280,)
            # make them the same shape
            ref_ulip_feature = ref_ulip_feature.reshape(1, -1)
            
            similarity_score = calculate_similarity(ulip_feature, ref_ulip_feature)
            similarity_scores.append((ref_modelId, similarity_score))
        # Sort the similarity scores
        similarity_scores.sort(key=lambda x: x[1], reverse=True)
        # Get the top 5 similar models
        top_5_similar_models = similarity_scores[:5]
        # Save the results to a json file
        for rank, (ref_modelId, similarity_score) in enumerate(top_5_similar_models):
            new_entry["retrieved_list"].append({
                "rank": rank + 1,
                "ref_model_id": ref_modelId,
                "ref_feature_path": os.path.join(ref_model_dir, ref_modelId, "ulip_feature.npy"),
                "similarity": float(similarity_score)
            })
        results.append(new_entry)
# Save the results to a json file
result_file = os.path.join("/home/davidyyd/3dm/Shapenet/Round2Processing/Mi_get_new", "Round2_Michelangelo_ULIP_similarity.json")


"""
{
        "query_model_id": "26cd3bfcef1e254f82b02baba7166175",
        "query_feature_path": "",
        "category": "get the category from metadata_df directly using modelId -> 'category'",
        "retrieved_list": [
            {
                "rank": 1,
                "ref_model_id": "5fba47ad66c45cd113314092564c13fd",
                "ref_feature_path": "",
                "similarity_score": "0.96818185"
            },
            {
                "rank": 2,
                "ref_model_id": "36221454034311a4fcaae723fa352fe6",
                "ref_feature_path": "",
                "similarity_score": "0.9641039"
            },
            {
                "rank": 3,
                "ref_model_id": "488b9ae283b800b282ec895e014b9eb3",
                "ref_feature_path": "",
                "similarity_score": "0.96365744"
            },
            {
                "rank": 4,
                "ref_model_id": "380433d04091e04d3270ed754ff7ec06",
                "ref_feature_path": "",
                "similarity_score": "0.956719"
            },
            {
                "rank": 5,
                "ref_model_id": "344e9402d06bd94031145076011658c5",
                "ref_feature_path": "",
                "similarity_score": "0.95468575"
            }
        ]
    },
"""

import json
import os
import shutil

import numpy as np
import pandas as pd
# Out:
# 100%|██████████| 1000/1000 [07:00<00:00,  2.38it/s]

# %%
with open(result_file, 'w') as f:
    json.dump(results, f, indent=4)
print(f"Results saved to {result_file}")
# Out:
# Results saved to /home/davidyyd/3dm/Shapenet/Round2Processing/Mi_get_new/Round2_Michelangelo_ULIP_similarity.json

# %%
import matplotlib.pyplot as plt
from collections import defaultdict

category_top1_sim = defaultdict(list)

for result in results:
    category = result["category"]
    top1_sim = result["retrieved_list"][0]["similarity"]
    category_top1_sim[category].append(top1_sim)
    
mean_top1_sim = {category: np.mean(sim) for category, sim in category_top1_sim.items()}
sorted_mean_top1_sim = dict(sorted(mean_top1_sim.items(), key=lambda item: item[1], reverse=True))
print(sorted_mean_top1_sim)
categories, mean_sims = zip(*sorted_mean_top1_sim.items())

plt.figure(figsize=(10, 6))
plt.bar(categories, mean_sims)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Mean Top-1 ULIP Similarity")
plt.title("Category-wise Mean Top-1 ULIP Similarity")
plt.tight_layout()
plt.grid(True, axis='y')
plt.show()
# Out:
# {'skateboard': 0.9297010093927384, 'airplane': 0.8618337482213974, 'faucet': 0.8573364049196244, 'bowl': 0.8556170046329499, 'car': 0.8474570930004119, 'laptop': 0.8473224878311157, 'bathtub': 0.8453454226255417, 'pillow': 0.8360796436667443, 'motorbike': 0.8323452234268188, 'bottle': 0.8232280194759369, 'bag': 0.8180895537137985, 'cap': 0.8115988776087761, 'telephone': 0.8027098774909973, 'guitar': 0.7992761641740799, 'piano': 0.7981678664684295, 'sofa': 0.7960155844688416, 'trash bin': 0.7931864857673645, 'bus': 0.7864740699529648, 'mailbox': 0.7854211390018463, 'mug': 0.7798882901668549, 'chair': 0.7729722082614898, 'pistol': 0.7717052966356277, 'table': 0.7702486902475357, 'bench': 0.7668143421411514, 'rocket': 0.7619272887706756, 'knife': 0.7592012524604798, 'display': 0.7521320775151252, 'rifle': 0.7495036393404007, 'washer': 0.7461837261915207, 'remote': 0.7432716369628907, 'jar': 0.7356335937976837, 'earphone': 0.7314336568117141, 'dishwasher': 0.728157214820385, 'can': 0.727
# ...

# %%
from matplotlib import cm
# 使用 pastel colormap（浅色）
cmap = cm.get_cmap('Pastel1', len(categories))
colors = [cmap(i) for i in range(len(categories))]

# 开始绘图
plt.figure(figsize=(12, 6))
bars = plt.bar(
    categories,
    mean_sims,
    color=colors,
    edgecolor='black',
    linewidth=1,  # 加粗边缘
    width=1
)

# 坐标轴美化
plt.xticks(rotation=45, ha='right', fontsize=11)
plt.yticks(fontsize=11)
plt.ylabel("Mean Top-1 ULIP Similarity", fontsize=13)
plt.title("Category-wise Mean Top-1 ULIP Similarity", fontsize=14, weight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1159291/2098027831.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('Pastel1', len(categories))
